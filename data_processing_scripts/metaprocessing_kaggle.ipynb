# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
## Loading the Data
corona_df = pd.read_csv('/kaggle/input/CORD-19-research-challenge/metadata.csv')

# %%
corona_df.shape #(51078, 18)
df_corona = corona_df.drop(columns = ['sha', 'source_x', 'pmcid', 'pubmed_id', 'authors', 'license', 'Microsoft Academic Paper ID', \
                               'WHO #Covidence', 'has_pdf_parse', 'has_pmc_xml_parse', 'full_text_file'])
df_corona.shape
df_corona.head(5)

# %%
covid19_synonyms = ['covid','coronavirus disease 19','sars cov 2','2019 ncov','2019ncov',r'2019 n cov\b', r'2019n cov\b',
                    'ncov 2019',r'\bn cov 2019','coronavirus 2019','wuhan pneumonia','wuhan virus','wuhan coronavirus',
                    r'coronavirus 2\b']
virus_origin = ['origin', 'genome', 'whole genome', 'genomics', 'RNA sequencing', 'spillover', 'spill-over', 'reservoir', 'bat']
transmission = ['transmission', 'incubation', 'asymptomatic shedding', 'environmental stability', 'contagious', 'disease models']
risk_factors = ['risk factor', 'co-infection', 'pre-existing', 'preexisting', 'co-existing', 'coexisting', 'smoking', 'co-morbidities', 'high-risk patient groups', 'susceptibility']
medical_care = ['surge capacity', 'surge medical staff', 'personal protective equipment', 'ppe', 'nursing facilities', 'long term care facilities', 'nursing homes', 'shortages']
diagnostics_surveillance = ['diagnostics', 'surveillance', 'screening', 'testing', 'mitigation measures', 'prevention', 'early detection', 'ELISA', 'rapid bed-side tests', 'PCR', 'CRISPR']
therapeutics = ['therapeutics', 'vaccines', 'drug development', 'animal model', 'viral inhibitors']
social_ethical = ['ethical', 'ethical considerations', 'ethics', 'novel ethical issues', 'secondary impacts', 'psychological', 'psychological health', 'stigma', 'fear', 'anxiety', 'misinformation','social media']
inventions = ['non-pharmaceutical interventions', 'school closure', 'travel ban', 'social distancing', 'social-distancing', 'cost and benefit', 'mass gatherings', 'funding']

# %%
#convert to all lower case 
df_corona['abstract'] = df_corona['abstract'].apply(lambda x: str(x).lower())

#remove all punctuations 
df_corona['abstract'] = df_corona['abstract'].str.replace('[^\w\s]','')

df_corona['abstract'].head(5)

# %%
## Dropping Dulpicates and NA values from abstract column
df_corona.drop_duplicates(['abstract'], inplace=True)
df_corona.dropna(subset=['abstract'], inplace=True)

df_corona.shape

# %%
import re 

virus_ori = [] 
for abstract in df_corona['abstract']:
    match_ = 0
    for keyword in virus_origin:
        if re.search(keyword, abstract):
            match_ +=1
            

    virus_ori.append(match_)
df_corona['virus_origin'] = virus_ori

# %%
transmission = ['transmission', 'incubation', 'asymptomatic shedding', 'environmental stability', 'contagious', 'disease models']
transmission_list = [] 
for abstract in df_corona['abstract']:
    match = 0
    for keyword in transmission:
        if re.search(keyword, abstract):
            match +=1
            

    transmission_list.append(match)
df_corona['transmission'] = transmission_list
df_corona.head(5)

# %%
risk_factors_list = []
for abstract in df_corona['abstract']:
    match = 0
    for keyword in risk_factors:
        if re.search(keyword, abstract):
            match +=1
            

    risk_factors_list.append(match)
df_corona['risk_factors'] = risk_factors_list
df_corona.head(5)

# %%
medical_care_list = []
for abstract in df_corona['abstract']:
    match = 0
    for keyword in medical_care:
        if re.search(keyword, abstract):
            match +=1
            

    medical_care_list.append(match)
df_corona['medical_care'] = medical_care_list
df_corona.head(5)

# %%
diagnostics_list = []
for abstract in df_corona['abstract']:
    match = 0
    for keyword in diagnostics_surveillance:
        if re.search(keyword, abstract):
            match +=1
            

    diagnostics_list.append(match)
df_corona['diagnostics_surveillance'] = diagnostics_list
df_corona.head(5)

# %%
therapeutics_list = []
for abstract in df_corona['abstract']:
    match = 0
    for keyword in therapeutics:
        if re.search(keyword, abstract):
            match +=1
            

    therapeutics_list.append(match)
df_corona['therapeutics'] = therapeutics_list
df_corona.head(5)

# %%
social_ethical_list = []
for abstract in df_corona['abstract']:
    match = 0
    for keyword in social_ethical:
        if re.search(keyword, abstract):
            match +=1
            

    social_ethical_list.append(match)
df_corona['social_ethical'] = social_ethical_list
df_corona.head(5)

# %%
inventions_list = []
for abstract in df_corona['abstract']:
    match = 0
    for keyword in inventions:
        if re.search(keyword, abstract):
            match +=1
            

    inventions_list.append(match)
df_corona['inventions'] = inventions_list
df_corona.head(10)

# %%
df_corona.to_csv('mycsvfile.csv',index=False)
